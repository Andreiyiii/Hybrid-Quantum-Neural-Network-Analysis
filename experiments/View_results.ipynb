# %% [markdown]
# ## Visualize HQNN ARHITECTURE

# %%
import numpy as np
from PIL import Image
from medmnist import RetinaMNIST
import pennylane as qml
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from sklearn.metrics import accuracy_score, roc_auc_score
import matplotlib.pyplot as plt
from typing import Tuple

# %% [markdown]
# ## need to import the build_model function from the ipynb file to work

# %%
#paste it here

# %%
num_classes = 5
in_channels = 1
model = build_model(num_classes=num_classes, in_channels=in_channels)
model.load_state_dict(torch.load("Saved_models/Resnet.pth"))
model.eval()

# %% [markdown]
# ## Visualize HQNN Model results:
# LOSS, ACC and ROC-AUC

# %%
with open("Saved_models/NAME.json", "r", encoding="utf-8") as fp:
    saved_history = json.load(fp)
epochs = np.arange(1, len(saved_history["train_loss"]) + 1)
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.plot(epochs, saved_history["train_loss"], label="train")
plt.plot(epochs, saved_history["val_loss"], label="val")
plt.title("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.subplot(1, 3, 2)
plt.plot(epochs, saved_history["train_acc"], label="train")
plt.plot(epochs, saved_history["val_acc"], label="val")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.subplot(1, 3, 3)
plt.plot(epochs, saved_history["train_auc"], label="train")
plt.plot(epochs, saved_history["val_auc"], label="val")
plt.title("AUC")
plt.xlabel("Epoch")
plt.legend()
plt.tight_layout()
plt.show()
